# %% [markdown]
# # Intelligent Semiotic Machine
#
# Publication information: de Lima Neto, F. B., Martins, D. M. L., & Vossen, G. (2018). A semiotic-inspired machine for personalized multi-criteria intelligent decision support. Data & Knowledge Engineering, 117, 225-238.
#
# URL: https://www.sciencedirect.com/science/article/abs/pii/S0169023X17300757
#
# Publication's BibTeX:
# ```
# @article{DELIMANETO2018225,
#     title = "A semiotic-inspired machine for personalized multi-criteria intelligent decision support",
#     journal = "Data & Knowledge Engineering",
#     volume = "117",
#     pages = "225 - 238",
#     year = "2018",
#     issn = "0169-023X",
#     doi = "https://doi.org/10.1016/j.datak.2018.07.012",
#     url = "http://www.sciencedirect.com/science/article/pii/S0169023X17300757",
#     author = "Fernando Buarque de Lima Neto and Denis Mayr Lima Martins and Gottfried Vossen",
#     keywords = "Multi-criteria decision support, Computational intelligence, Computational semiotics, Intelligent semiotic machine",
#     abstract = "The need for appropriate decisions to tackle complex problems increases every day. Selecting destinations for vacation, comparing and optimizing resources to create valuable products, or purchasing a suitable car are just a few examples of puzzling situations in which there is no standard form to find an appropriate solution. Such scenarios become arduous when the number of possibilities, restrictions, and factors affecting the decision rise, thereby turning decision makers into almost mere spectators. In such circumstances, decision support systems (DSS) can play an important role in guiding people and organizations towards more accurate decision making. However, conventional DSS lack the necessary adaptability to account for dynamic changes and are frequently inadequate to tackle the subjectivity inherent in decision-maker's preferences and intention. We argue that these shortcomings can be addressed by a suitable combination of Semiotic Theory and Computational Intelligence algorithms, which together can make up a new generation of DSS. In this article, a formal description of an Intelligent Semiotic Machine is provided and tried out in practical decision contexts. The results obtained show that our approach can provide well-suited decisions based on user preferences, achieving appropriateness while fanning out subjective options without losing decision context, objectivity, or accuracy."
# }
# ```

# %% [markdown]
# ## Configuring the notebook

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from models.semioticmodule import SemioticModule
import util
from models.car import Car
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting the data set and the user input

# %%
original_cars, cars, preprocessed_data = util.get_cars()
semiotic_module = SemioticModule(cars, original_cars, preprocessed_data)
customer = util.get_customers_view()[0]
preferences = customer.preferences

# %% [markdown]
# ## Using the Intelligent Semiotic Machine to filter candidates

# %%
selected_candidates, optimal_candidates, similar_candidates = semiotic_module.get_recommendations(preferences, customer.criteria, show_discrimination_graph=True)
# Out:
# C:\Users\d_mart04\Python\lib\site-packages\sklearn\base.py:253: UserWarning: Trying to unpickle estimator KMeans from version pre-0.18 when using version 0.20.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
selected_candidates
# Out:
#             make manufacturer     type   price   mpg  num_of_cylinders  \
# 35    Ford Probe         Ford   Sporty  7000.0  27.0                 4
# 34  Ford Mustang         Ford   Sporty  7950.0  25.5                 4
# 31  Ford Festiva         Ford    Small  3700.0  32.0                 4
# 32   Ford Escort         Ford    Small  5050.0  26.5                 4
# 33    Ford Tempo         Ford  Compact  5650.0  24.5                 4
#
#     horsepower  fuel_tank_capacity   RPM  Wheelbase  ...  Weight  \
# 35         115                15.5  5500        103  ...    2710
# 34         105                15.4  4600        101  ...    2850
# 31          63                10.0  5000         90  ...    1845
# 32         127                13.2  6500         98  ...    2530
# 33          96                15.9  4200        100  ...    2690
#
#     automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 35                  0                   4     179     70              18.0
# 34                  0                   4     180     68              12.0
# 31                  0                   4     141     63              12.0
# 32                  0                   5     171     67              12.0
# 33                  0                   5     177     68              13.0
#
#         AirBags DriveTrain Origin           imagepath
# 35  Driver only      Front      0    35Ford_Probe.jpg
# 34  Driver only       Rear      0  34ford_mustang.jpg
# 31         None      Front      0  31Ford_Festiva.jpg
# 32         None      Front      0   32Ford_Escort.jpg
# 33         None      Front      0    33Ford_Tempo.jpg
#
# [5 rows x 21 columns]

# %%
optimal_candidates
# Out:
#             make manufacturer   type   price   mpg  num_of_cylinders  \
# 31  Ford Festiva         Ford  Small  3700.0  32.0                 4
# 32   Ford Escort         Ford  Small  5050.0  26.5                 4
#
#     horsepower  fuel_tank_capacity   RPM  Wheelbase  ...  Weight  \
# 31          63                10.0  5000         90  ...    1845
# 32         127                13.2  6500         98  ...    2530
#
#     automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 31                  0                   4     141     63              12.0
# 32                  0                   5     171     67              12.0
#
#     AirBags DriveTrain Origin           imagepath
# 31     None      Front      0  31Ford_Festiva.jpg
# 32     None      Front      0   32Ford_Escort.jpg
#
# [2 rows x 21 columns]

# %%
similar_candidates
# Out:
#             make manufacturer   type   price   mpg  num_of_cylinders  \
# 23    Dodge Colt        Dodge  Small  4600.0  31.0                 4
# 29  Eagle Summit        Eagle  Small  6100.0  31.0                 4
#
#     horsepower  fuel_tank_capacity   RPM  Wheelbase  ...  Weight  \
# 23          92                13.2  6000         98  ...    2270
# 29          92                13.2  6000         98  ...    2295
#
#     automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 23                  0                   5     174     66              11.0
# 29                  0                   5     174     66              11.0
#
#     AirBags DriveTrain Origin           imagepath
# 23     None      Front      0    23dodge_colt.jpg
# 29     None      Front      0  29Eagle_Summit.jpg
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Adding more preferences and checking results
# We simulate the case where the user provides more information about the cars she wants to find.

# %%
additional = util.get_additional_preferences()

# %% [markdown]
# ### Checking results
# We use the first element of the list of additional preferences. To add more preferences, we can just change the index in the next cell

# %%
preferences.append(additional[0])
selected_candidates, optimal_candidates, similar_candidates = semiotic_module.get_recommendations(preferences, customer.criteria)

# %%
selected_candidates
# Out:
#                 make manufacturer    type   price   mpg  num_of_cylinders  \
# 14  Chevrolet Camaro    Chevrolet  Sporty  7550.0  23.5                 6
# 35        Ford Probe         Ford  Sporty  7000.0  27.0                 4
# 75  Pontiac Firebird      Pontiac  Sporty  8850.0  23.5                 6
# 34      Ford Mustang         Ford  Sporty  7950.0  25.5                 4
# 36     Ford Aerostar         Ford     Van  9950.0  17.5                 6
#
#     horsepower  fuel_tank_capacity   RPM  Wheelbase  ...  Weight  \
# 14         160                15.5  4600        101  ...    3240
# 35         115                15.5  5500        103  ...    2710
# 75         160                15.5  4600        101  ...    3240
# 34         105                15.4  4600        101  ...    2850
# 36         145                21.0  4800        119  ...    3735
#
#     automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 14                  0                   4     193     74         13.000000
# 35                  0                   4     179     70         18.000000
# 75                  0                   4     196     75         13.000000
# 34                  0                   4     180     68         12.000000
# 36                  0                   7     176     72         18.025546
#
#                AirBags DriveTrain Origin               imagepath
# 14  Driver & Passenger       Rear      0  14chevrolet_camaro.jpg
# 35         Driver only      Front      0        35Ford_Probe.jpg
# 75  Driver & Passenger       Rear      0  75Pontiac_Firebird.jpg
# 34         Driver only       Rear      0      34ford_mustang.jpg
# 36         Driver only        4WD      0     36Ford_Aerostar.jpg
#
# [5 rows x 21 columns]

# %%
optimal_candidates
# Out:
#                 make manufacturer    type   price   mpg  num_of_cylinders  \
# 14  Chevrolet Camaro    Chevrolet  Sporty  7550.0  23.5                 6
# 35        Ford Probe         Ford  Sporty  7000.0  27.0                 4
# 75  Pontiac Firebird      Pontiac  Sporty  8850.0  23.5                 6
#
#     horsepower  fuel_tank_capacity   RPM  Wheelbase  ...  Weight  \
# 14         160                15.5  4600        101  ...    3240
# 35         115                15.5  5500        103  ...    2710
# 75         160                15.5  4600        101  ...    3240
#
#     automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 14                  0                   4     193     74              13.0
# 35                  0                   4     179     70              18.0
# 75                  0                   4     196     75              13.0
#
#                AirBags DriveTrain Origin               imagepath
# 14  Driver & Passenger       Rear      0  14chevrolet_camaro.jpg
# 35         Driver only      Front      0        35Ford_Probe.jpg
# 75  Driver & Passenger       Rear      0  75Pontiac_Firebird.jpg
#
# [3 rows x 21 columns]

# %%
similar_candidates
# Out:
#                   make manufacturer     type    price   mpg  num_of_cylinders  \
# 19  Chevrolet Corvette    Chevrolet   Sporty  19000.0  21.0                 8
# 12  Chevrolet Cavalier    Chevrolet  Compact   6700.0  30.5                 4
# 13   Chevrolet Corsica    Chevrolet  Compact   5700.0  29.5                 4
#
#     horsepower  fuel_tank_capacity   RPM  Wheelbase  ...  Weight  \
# 19         300                20.0  5000         96  ...    3380
# 12         110                15.2  5200        101  ...    2490
# 13         110                15.6  5200        103  ...    2785
#
#     automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 19                  0                   2     179     74         17.203669
# 12                  0                   5     182     66         13.000000
# 13                  0                   5     184     68         14.000000
#
#         AirBags DriveTrain Origin                  imagepath
# 19  Driver only       Rear      0  19chevrolet_corvette.jpeg
# 12         None      Front      0   12chevrolet_cavalier.jpg
# 13  Driver only      Front      0    13Chevrolet_Corsica.jpg
#
# [3 rows x 21 columns]
