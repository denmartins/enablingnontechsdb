# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# /home/dmartins/GitWorkspace/phd-query-synthesis/PhDCoding

# %%
# Source: https://scikit-criteria.readthedocs.io/en/latest/index.html
from skcriteria import Data, MIN, MAX
from skcriteria.madm import closeness, simple
import pandas as pd
import os

# %%
providers = pd.read_pickle(os.path.join('datasets', 'uci-original-no-na.pkl'))
providers['Year'] = providers['Year'].astype('int32')
providers['NumInstances'] = providers['NumInstances'].astype('int32')
providers['Price'] = providers['Price']/15

providers.shape
# Out:
# (81, 10)

# %%
selected_providers = providers[providers.Area == 'Life']
selected_providers.shape
# Out:
# (37, 10)

# %%
preprocessed_data = pd.read_pickle(os.path.join('datasets', 'uci-preprocessed.pkl'))
preprocessed_data['Price'] = preprocessed_data['Price']/5

# %%
def export_to_latex(dataframe, relevance=False):
    latex_cols = ['Name', 'NumAttributes', 'NumInstances', 'Year', 'MissingValues', 'Price']
    if relevance:
        latex_cols = latex_cols + ['Relevance']
    else:
        latex_cols = latex_cols + ['TopsisRank']
        
    print(dataframe[latex_cols][:10].to_latex(index=False))

# %%
# Use only the attributes that are important to the decision
columns_assessment_view = ['NumInstances', 'Year', 'MissingValues', 'Price']
assessment_view = preprocessed_data.loc[selected_providers.index][columns_assessment_view]
# Get names of the selected options
names = selected_providers.Name.values

# %%
criteria = [MAX, MAX, MIN, MIN]
weights = [0.49, 0.01, 0.01, 0.49]#[0.25, 0.15, 0.15, 0.45]#[0.25, 0.15, 0.35, 0.25]

# %%
mcda_data = Data(assessment_view.as_matrix().tolist(), criteria, weights=weights, anames=names, cnames=columns_assessment_view)
# Out:
# /home/dmartins/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
model = closeness.TOPSIS()
decision = model.decide(mcda_data)
decision
# Out:
# TOPSIS (mnorm=vector, wnorm=sum) - Solution:
#                     ALT./CRIT.                       NumInstances (max) W.0.49    Year (max) W.0.01    MissingValues (min) W.0.01    Price (min) W.0.49    Rank
# --------------------------------------------------  ---------------------------  -------------------  ----------------------------  --------------------  ------
#                      Abalone                                 0.0010809                  0.32                       1                      0.152868          35
#                     Arrhythmia                              0.000113492                 0.44                       0                     0.0491349          17
#              Audiology (Standardized)                       5.47982e-05                  0.2                       0                      0.012566          4
#                   Breast Cancer                             7.03807e-05                 0.04                       0                     0.0129302          5
#         Breast Cancer Wisconsin (Original)                  0.00017764                   0.2                       0                     0.0639592          22
#        Breast Cancer Wisconsin (Prognostic)                 4.75264e-05                 0.32                       0                     0.0336915          9
#        Breast Cancer Wisconsin (Diagnostic)                 0.000143878                 0.32                       1                     0.0822072          27
#            Contraceptive Method Choice                      0.000378653                  0.4                       1                      0.145365          33
#                     Covertype                                0.150889                   0.44                       1                      0.157968          1
#                    Dermatology                              9.11572e-05                 0.44                       0                      0.051466          18
#                   Echocardiogram                            3.03857e-05                 0.08                       0                         0              2
#                       Ecoli                                 8.3366e-05                  0.36                       1                     0.0558004          20
#                Haberman's Survival                          7.55748e-05                 0.48                       1                     0.0756511          26
#                   Heart Disease                             7.47957e-05                 0.04                       0                     0.0402841          11
#                     Hepatitis                               3.6359e-05                  0.04                       0                     0.00466217         3
#                    Horse Colic                              9.16766e-05                 0.08                       0                     0.0403569          12
#                        Iris                                 3.50605e-05                 0.04                       1                     0.0417046          13
#                    Lung Cancer                              4.41502e-06                  0.2                       0                     0.0281187          8
#                    Lymphography                             3.45411e-05                 0.04                       1                     0.0423602          15
#    Molecular Biology (Promoter Gene Sequences)              2.36334e-05                 0.12                       1                     0.0515753          19
# Molecular Biology (Splice-junction Gene Sequences)          0.00082457                   0.2                       1                      0.157239          36
#                  MONK's Problems                            0.000108298                  0.2                       1                     0.0824258          28
#                      Mushroom                               0.00210597                    0                        0                      0.10978           32
#               Pima Indians Diabetes                         0.00019556                  0.12                       0                     0.0485522          16
#               Post-Operative Patient                        1.9478e-05                  0.24                       0                     0.0279366          7
#                   Primary Tumor                             8.41451e-05                 0.04                       0                     0.0419596          14
#                  Soybean (Large)                            7.58345e-05                 0.04                       0                     0.0265161          6
#                  Soybean (Small)                            8.31063e-06                   0                        1                     0.0641049          23
#                    SPECT Heart                              6.54462e-05                 0.56                       1                     0.0688763          24
#                    SPECTF Heart                             6.54462e-05                 0.56                       1                     0.0730286          25
#                       Yeast                                 0.00038151                  0.36                       1                      0.145438          34
#                        Zoo                                  2.23348e-05                 0.12                       1                     0.0362775          10
#                 Mammographic Mass                           0.000245683                  0.8                       0                     0.0878529          30
#                       Plants                                 0.0058738                  0.84                       0                      0.109743          31
#                Acute Inflammations                          2.72693e-05                 0.88                       1                     0.0613732          21
#                    p53 Mutants                              0.00435191                  0.92                       0                      0.179312          37
#    KEGG Metabolic Reaction Network (Undirected)              0.017021                   0.96                       0                      0.117793          29

# %%
print("Ideal:", decision.e_.ideal)
print("Anti-Ideal:", decision.e_.anti_ideal)
print("Closeness:", decision.e_.closeness)
# Out:
# Ideal: [0.48627681 0.00380139 0.         0.        ]
# Anti-Ideal: [1.42284828e-05 0.00000000e+00 2.42535625e-03 1.71883057e-01]
# Closeness: [0.04831562 0.20361718 0.24741357 0.24701879 0.18428779 0.22273556
#  0.15905785 0.0606771  0.76266383 0.20060826 0.26121047 0.19494808
#  0.1682181  0.21468256 0.25615845 0.21461196 0.21284461 0.2293648
#  0.21202721 0.20034568 0.04041793 0.15870797 0.12015044 0.20443207
#  0.2296002  0.212612   0.23134353 0.18388119 0.17753139 0.17184705
#  0.06054176 0.21952463 0.15118706 0.12660306 0.18761986 0.02837865
#  0.15315932]

# %%
best_alternative = selected_providers.iloc[int(decision.best_alternative_)]
selected_providers.loc[selected_providers['Name'] == best_alternative['Name']]
# Out:
#          Name      DataTypes      DefaultTask         AttributeTypes  \
# 16  Covertype  Multivariate   Classification   Categorical, Integer
#
#     NumInstances NumAttributes  Year MissingValues  Area       Price  \
# 16        581012           54   1998            No  Life  381.266667
#
#     TopsisRank
# 16           1

# %%
selected_providers['TopsisRank'] = decision.rank_
# Out:
# /home/dmartins/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
topsis_result = selected_providers.sort_values(by='TopsisRank')
topsis_result[:10]
# Out:
#                                     Name      DataTypes  \
# 16                             Covertype  Multivariate
# 19                        Echocardiogram  Multivariate
# 25                             Hepatitis  Multivariate
# 4               Audiology (Standardized)  Multivariate
# 6                          Breast Cancer  Multivariate
# 52                       Soybean (Large)  Multivariate
# 47                Post-Operative Patient  Multivariate
# 33                           Lung Cancer  Multivariate
# 8   Breast Cancer Wisconsin (Prognostic)  Multivariate
# 64                                   Zoo  Multivariate
#
#                     DefaultTask               AttributeTypes  NumInstances  \
# 16              Classification         Categorical, Integer         581012
# 19              Classification   Categorical, Integer, Real            132
# 25              Classification   Categorical, Integer, Real            155
# 4               Classification                  Categorical            226
# 6               Classification                  Categorical            286
# 52              Classification                  Categorical            307
# 47              Classification         Categorical, Integer             90
# 33              Classification                      Integer             32
# 8   Classification, Regression                         Real            198
# 64              Classification         Categorical, Integer            101
#
#    NumAttributes  Year MissingValues  Area       Price  TopsisRank
# 16           54   1998            No  Life  381.266667           1
# 19           12   1989           Yes  Life   92.133333           2
# 25           19   1988           Yes  Life  100.666667           3
# 4            69   1992           Yes  Life  115.133333           4
# 6             9   1988           Yes  Life  115.800000           5
# 52           35   1988           Yes  Life  140.666667           6
# 47            8   1993           Yes  Life  143.266667           7
# 33           56   1992           Yes  Life  143.600000           8
# 8            34   1995           Yes  Life  153.800000           9
# 64           17   1990            No  Life  158.533333          10

# %%
export_to_latex(topsis_result, relevance=False)
# Out:
# \begin{tabular}{llrrlrr}
# \toprule
#                                  Name & NumAttributes &  NumInstances &  Year & MissingValues &       Price &  TopsisRank \\
# \midrule
#                             Covertype &           54  &        581012 &  1998 &            No &  381.266667 &           1 \\
#                        Echocardiogram &           12  &           132 &  1989 &           Yes &   92.133333 &           2 \\
#                             Hepatitis &           19  &           155 &  1988 &           Yes &  100.666667 &           3 \\
#              Audiology (Standardized) &           69  &           226 &  1992 &           Yes &  115.133333 &           4 \\
#                         Breast Cancer &            9  &           286 &  1988 &           Yes &  115.800000 &           5 \\
#                       Soybean (Large) &           35  &           307 &  1988 &           Yes &  140.666667 &           6 \\
#                Post-Operative Patient &            8  &            90 &  1993 &           Yes &  143.266667 &           7 \\
#                           Lung Cancer &           56  &            32 &  1992 &           Yes &  143.600000 &           8 \\
#  Breast Cancer Wisconsin (Prognostic) &           34  &           198 &  1995 &           Yes &  153.800000 &           9 \\
#                                   Zoo &           17  &           101 &  1990 &            No &  158.533333 &          10 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### Hard constraints

# %%
selected_providers.query("MissingValues =='No' and Price <= 190 and NumInstances >= 200 and Year >= 1990")
# Out:
# Empty DataFrame
# Columns: [Name, DataTypes, DefaultTask, AttributeTypes, NumInstances, NumAttributes, Year, MissingValues, Area, Price, TopsisRank]
# Index: []

# %% [markdown]
# ## Using the iSM

# %% [markdown]
# ### Selecting providers using preferences as soft constraints

# %%
def evaluate(provider, iteration):
    budget = 190
    year = 1990
    rows = 200
    
    relnulval = int(provider['MissingValues'] == 'No')
    
    relprice = budget - provider['Price']
    
    relyear = provider['Year'] - year 
    
    relrows = provider['NumInstances'] - rows
    
    if iteration < 2:
        relnulval = 0
        
    if iteration < 3:
        relrows = 0
    
    score = relprice/max(selected_providers['Price']) + relyear/max(selected_providers['Year']) + relrows/max(selected_providers['NumInstances']) + relnulval
    
    return float(str.format('{:.3f}',  score))

# %%
selected_providers['Relevance'] = [evaluate(selected_providers.iloc[i], iteration=3) for i in range(selected_providers.shape[0])]
# Out:
# /home/dmartins/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ism_selected = selected_providers.sort_values(by='Relevance', ascending=False)[:10]
ism_selected
# Out:
#                                            Name                   DataTypes  \
# 16                                    Covertype               Multivariate
# 64                                          Zoo               Multivariate
# 29                                         Iris               Multivariate
# 34                                 Lymphography               Multivariate
# 36  Molecular Biology (Promoter Gene Sequences)  Sequential, Domain-Theory
# 20                                        Ecoli               Multivariate
# 74                          Acute Inflammations               Multivariate
# 53                              Soybean (Small)               Multivariate
# 56                                  SPECT Heart               Multivariate
# 57                                 SPECTF Heart               Multivariate
#
#         DefaultTask         AttributeTypes  NumInstances NumAttributes  Year  \
# 16  Classification   Categorical, Integer         581012           54   1998
# 64  Classification   Categorical, Integer            101           17   1990
# 29  Classification                   Real            150            4   1988
# 34  Classification            Categorical            148           18   1988
# 36  Classification            Categorical            106           58   1990
# 20  Classification                   Real            336            8   1996
# 74  Classification   Categorical, Integer            120            6   2009
# 53  Classification            Categorical             47           35   1987
# 56  Classification            Categorical            267           22   2001
# 57  Classification                Integer            267           44   2001
#
#    MissingValues  Area       Price  TopsisRank  Relevance
# 16            No  Life  381.266667           1      1.549
# 64            No  Life  158.533333          26      1.075
# 29            No  Life  168.466667          28      1.050
# 34            No  Life  169.666667          29      1.047
# 36            No  Life  186.533333          30      1.008
# 20            No  Life  194.266667          24      0.993
# 74            No  Life  204.466667           7      0.975
# 53            No  Life  209.466667          32      0.952
# 56            No  Life  218.200000          22      0.938
# 57            No  Life  225.800000          23      0.920

# %%
export_to_latex(ism_selected, relevance=True)
# Out:
# \begin{tabular}{llrrlrr}
# \toprule
#                                         Name & NumAttributes &  NumInstances &  Year & MissingValues &       Price &  Relevance \\
# \midrule
#                                    Covertype &           54  &        581012 &  1998 &            No &  381.266667 &      1.549 \\
#                                          Zoo &           17  &           101 &  1990 &            No &  158.533333 &      1.075 \\
#                                         Iris &            4  &           150 &  1988 &            No &  168.466667 &      1.050 \\
#                                 Lymphography &           18  &           148 &  1988 &            No &  169.666667 &      1.047 \\
#  Molecular Biology (Promoter Gene Sequences) &           58  &           106 &  1990 &            No &  186.533333 &      1.008 \\
#                                        Ecoli &            8  &           336 &  1996 &            No &  194.266667 &      0.993 \\
#                          Acute Inflammations &            6  &           120 &  2009 &            No &  204.466667 &      0.975 \\
#                              Soybean (Small) &           35  &            47 &  1987 &            No &  209.466667 &      0.952 \\
#                                  SPECT Heart &           22  &           267 &  2001 &            No &  218.200000 &      0.938 \\
#                                 SPECTF Heart &           44  &           267 &  2001 &            No &  225.800000 &      0.920 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### Select pareto-front

# %%
def identify_pareto(scores):
    # Count number of items
    population_size = scores.shape[0]
    # Create a NumPy index for scores on the pareto front (zero indexed)
    population_ids = np.arange(population_size)
    # Create a starting list of items on the Pareto front
    # All items start off as being labelled as on the Parteo front
    pareto_front = np.ones(population_size, dtype=bool)
    # Loop through each item. This will then be compared with all other items
    for i in range(population_size):
        # Loop through all other items
        for j in range(population_size):
            # Check if our 'i' pint is dominated by out 'j' point
            if all(scores[j] >= scores[i]) and any(scores[j] > scores[i]):
                # j dominates i. Label 'i' point as not on Pareto front
                pareto_front[i] = 0
                # Stop further comparisons with 'i' (no more comparisons needed)
                break
    # Return ids of scenarios on pareto front
    return population_ids[pareto_front]

# %%
pareto_columns = [columns_assessment_view[0], columns_assessment_view[-1]]
pareto_criteria = [criteria[0], criteria[-1]]
data_pareto_analysis = assessment_view[pareto_columns].loc[ism_selected.index].copy(deep=True)

# %%
for i in range(len(pareto_criteria)):
    if pareto_criteria[i] == MIN:
        data_pareto_analysis[data_pareto_analysis.columns[i]] = 1/data_pareto_analysis[data_pareto_analysis.columns[i]]

# %%
pareto_index = identify_pareto(data_pareto_analysis.values)

# %%
ism_pareto = ism_selected.iloc[pareto_index].sort_values(by='Relevance', ascending=False)
ism_pareto
# Out:
#          Name      DataTypes      DefaultTask         AttributeTypes  \
# 16  Covertype  Multivariate   Classification   Categorical, Integer
# 64        Zoo  Multivariate   Classification   Categorical, Integer
# 29       Iris  Multivariate   Classification                   Real
# 20      Ecoli  Multivariate   Classification                   Real
#
#     NumInstances NumAttributes  Year MissingValues  Area       Price  \
# 16        581012           54   1998            No  Life  381.266667
# 64           101           17   1990            No  Life  158.533333
# 29           150            4   1988            No  Life  168.466667
# 20           336            8   1996            No  Life  194.266667
#
#     TopsisRank  Relevance
# 16           1      1.549
# 64          26      1.075
# 29          28      1.050
# 20          24      0.993

# %% [markdown]
# #### Discriminating providers with SOM

# %%
import somoclu

# %%
data = preprocessed_data.loc[selected_providers.index].copy(deep=True)
del data['Name']

data = np.apply_along_axis(lambda x: x/np.linalg.norm(x), 1, data)

x_size = 8
y_size = 4
sigma = max(x_size, y_size)*0.2
labels = [providers.iloc[i]['Name'] for i in range(providers.shape[0])]

som = somoclu.Somoclu(n_columns=x_size, n_rows=y_size, compactsupport=False, initialization='pca')
# %time som.train(data=data, epochs=1000, radius0=sigma)
# Out:
# Warning: data was not float32. A 32-bit copy was made
# CPU times: user 607 ms, sys: 16.1 ms, total: 623 ms
# Wall time: 220 ms

# %%
fig = som.view_umatrix(bestmatches=True, labels=selected_providers['Name'].index, colorbar=True, figsize=(x_size*2, y_size*2))

# %% [raw]
# label_names = labels
# labels_map = dict()
# for p in range(len(som.bmus)):
#     position = tuple(som.bmus[p].tolist())
#     if not position in labels_map.keys():
#         labels_map[position] = []
#     labels_map[position] = labels_map[position] + [labels[p]]

# %% [raw]
# import matplotlib.pyplot as plt
# from matplotlib.gridspec import GridSpec
#
# plt.figure(figsize=(x_size*1.5, y_size*1.5))
# plt.set_cmap('Dark2')
# the_grid = GridSpec(x_size, y_size)
# for p in som.bmus:
#     position = tuple(p.tolist())
#     labels_frac = [int(l in labels_map[position]) for l in labels]
#     #label_fracs = [labels_map[position][l] for l in label_names]
#     plt.subplot(the_grid[position[0], position[1]], aspect=1)
#     patches, texts = plt.pie(label_fracs)
# plt.legend(patches, label_names, bbox_to_anchor=(5.5, 1.5), ncol=3)
# #plt.savefig('som_car_pies.png')
# plt.show()

# %%
def get_neighborhood(centroid_2d_position, step, x_size, y_size):
    search_space = [(centroid_2d_position[0], centroid_2d_position[1]),
                    (centroid_2d_position[0], centroid_2d_position[1]-step), 
                    (centroid_2d_position[0]-step, centroid_2d_position[1]-step),
                    (centroid_2d_position[0]-step, centroid_2d_position[1]),
                    (centroid_2d_position[0]-step, centroid_2d_position[1]+step), 
                    (centroid_2d_position[0], centroid_2d_position[1]+step),
                    (centroid_2d_position[0]+step, centroid_2d_position[1]+step),
                    (centroid_2d_position[0]+step, centroid_2d_position[1]),
                    (centroid_2d_position[0]+step, centroid_2d_position[1]-step)]

    neighborhood = []
    for region in search_space:
        if region[0] in range(x_size) and region[1] in range(y_size):
            neighborhood.append(list(region))

    return neighborhood

# %%
similar = {}
for j in range(ism_pareto.shape[0]):
    similar[ism_pareto.index[j]] = [selected_providers.index[i] for i in range(selected_providers.shape[0]) if som.bmus[i].tolist() in get_neighborhood(som.bmus[j-1], 0, x_size, y_size)]

# %%
ids = set()
for k,v in similar.items():
    for e in v:
        ids.add(e)
ids = list(ids)

# %%
providers.loc[[i for i in ids if not i in ism_selected.index]]
# Out:
#                                             Name  \
# 0                                        Abalone
# 2                                     Arrhythmia
# 4                       Audiology (Standardized)
# 6                                  Breast Cancer
# 39                                      Mushroom
# 8           Breast Cancer Wisconsin (Prognostic)
# 77  KEGG Metabolic Reaction Network (Undirected)
# 48                                 Primary Tumor
# 19                                Echocardiogram
# 52                               Soybean (Large)
# 24                                 Heart Disease
# 25                                     Hepatitis
# 26                                   Horse Colic
#
#                           DataTypes                              DefaultTask  \
# 0                     Multivariate                           Classification
# 2                     Multivariate                           Classification
# 4                     Multivariate                           Classification
# 6                     Multivariate                           Classification
# 39                    Multivariate                           Classification
# 8                     Multivariate               Classification, Regression
# 77  Multivariate, Univariate, Text   Classification, Regression, Clustering
# 48                    Multivariate                           Classification
# 19                    Multivariate                           Classification
# 52                    Multivariate                           Classification
# 24                    Multivariate                           Classification
# 25                    Multivariate                           Classification
# 26                    Multivariate                           Classification
#
#                  AttributeTypes  NumInstances NumAttributes  Year  \
# 0   Categorical, Integer, Real           4177            8   1995
# 2   Categorical, Integer, Real            452          279   1998
# 4                  Categorical            226           69   1992
# 6                  Categorical            286            9   1988
# 39                 Categorical           8124           22   1987
# 8                         Real            198           34   1995
# 77               Integer, Real          65554           29   2011
# 48                 Categorical            339           17   1988
# 19  Categorical, Integer, Real            132           12   1989
# 52                 Categorical            307           35   1988
# 24  Categorical, Integer, Real            303           75   1988
# 25  Categorical, Integer, Real            155           19   1988
# 26  Categorical, Integer, Real            368           27   1989
#
#    MissingValues  Area       Price
# 0             No  Life  371.933333
# 2            Yes  Life  182.066667
# 4            Yes  Life  115.133333
# 6            Yes  Life  115.800000
# 39           Yes  Life  293.066667
# 8            Yes  Life  153.800000
# 77           Yes  Life  307.733333
# 48           Yes  Life  168.933333
# 19           Yes  Life   92.133333
# 52           Yes  Life  140.666667
# 24           Yes  Life  165.866667
# 25           Yes  Life  100.666667
# 26           Yes  Life  166.000000

# %%
similar
# Out:
# {16: [8, 77], 64: [0], 29: [2, 19, 24, 25, 26], 20: [4, 6, 39, 48, 52]}

# %%
export_to_latex(selected_providers.loc[similar[20]], relevance=True)
# Out:
# \begin{tabular}{llrrlrr}
# \toprule
#                      Name & NumAttributes &  NumInstances &  Year & MissingValues &       Price &  Relevance \\
# \midrule
#  Audiology (Standardized) &           69  &           226 &  1992 &           Yes &  115.133333 &      0.179 \\
#             Breast Cancer &            9  &           286 &  1988 &           Yes &  115.800000 &      0.176 \\
#                  Mushroom &           22  &          8124 &  1987 &           Yes &  293.066667 &     -0.233 \\
#             Primary Tumor &           17  &           339 &  1988 &           Yes &  168.933333 &      0.049 \\
#           Soybean (Large) &           35  &           307 &  1988 &           Yes &  140.666667 &      0.117 \\
# \bottomrule
# \end{tabular}
