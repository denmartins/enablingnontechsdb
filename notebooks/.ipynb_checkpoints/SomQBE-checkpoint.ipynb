# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ..
# Out:
# C:\Users\d_mart04\Google Drive\Doutorado\gitworkspace\phd-query-synthesis\PhDCoding

# %%
import sys, os
sys.path.append('..\\PhDCoding\\decision')
sys.path.append('..\\PhDCoding\\qbe')

# %%
from IPython.display import Image, HTML
from decision.somselector import SomSelector
from qbe.deapgpqbe import DEAPGeneticProgrammingQBE
from qbe.fitfunction import QueryDiscoveryFitnessFunction
from qbe.treeqbe import DecisionTreeQBE
from qbe import util
import pandas as pd, pandasql as pdsql
import re

# %%
def show_images(indices):
    for i in indices:
        print("ID:{} - {}".format(i, dataset.original_data.iloc[i]['make']))
        display(Image(filename=(images[i]), width=300))

# %%
class Dataset(object):
    def __init__(self, original_data, preprocessed_data):
        self.original_data = original_data
        self.preprocessed_data = preprocessed_data
        self.data_matrix = preprocessed_data.as_matrix()

    def get_original_indices(self, tuples):
        indices = []
        for row in tuples.values:
            for i in range(self.original_data.shape[0]):
                if (row == self.original_data[i]).all():
                    indices.append(i)

        return indices

# %% [markdown]
# ### Loading and configuring car dataset

# %%
cartable = pd.read_pickle('datasets\\car_original_dataset.pkl')
cartable.columns = [str.lower(col.replace('.', '_')) for col in cartable.columns]
cartable['origin'] = cartable['origin'].map({0: False, 1: True})
cartable['automatic_gearbox'] = cartable['automatic_gearbox'].map({0: False, 1: True})

# %%
images = ["car-images\\" + str(x) for x in cartable['imagepath']]
del cartable['imagepath']

# %%
cartable
# Out:
#                         make manufacturer     type    price   mpg  \
# 1              Acura Integra        Acura    Small   7950.0  28.0
# 2               Acura Legend        Acura  Midsize  16950.0  21.5
# 3                    Audi 90         Audi  Compact  14550.0  23.0
# 4                   Audi 100         Audi  Midsize  18850.0  22.5
# 5                   BMW 535i          BMW  Midsize  15000.0  26.0
# 6              Buick Century        Buick  Midsize   7850.0  26.5
# 7              Buick LeSabre        Buick    Large  10400.0  23.5
# 8           Buick Roadmaster        Buick    Large  11850.0  20.5
# 9              Buick Riviera        Buick  Midsize  13150.0  23.0
# 10          Cadillac DeVille     Cadillac    Large  17350.0  20.5
# 11          Cadillac Seville     Cadillac  Midsize  20050.0  20.5
# 12        Chevrolet Cavalier    Chevrolet  Compact   6700.0  30.5
# 13         Chevrolet Corsica    Chevrolet  Compact   5700.0  29.5
# 14          Chevrolet Camaro    Chevrolet   Sporty   7550.0  23.5
# 15          Chevrolet Lumina    Chevrolet  Midsize   7950.0  25.0
# 16      Chevrolet Lumina_APV    Chevrolet      Van   8150.0  20.5
# 17           Chevrolet Astro    Chevrolet      Van   8300.0  17.5
# 18         Chevrolet Caprice    Chevrolet    Large   9400.0  21.5
# 19        Chevrolet Corvette    Chevrolet   Sporty  19000.0  21.0
# 20         Chrylser Concorde     Chrysler    Large   9200.0  24.0
# 21          Chrysler LeBaron     Chrysler  Compact   7900.0  25.5
# 22         Chrysler Imperial     Chrysler    Large  14750.0  23.0
# 23                Dodge Colt        Dodge    Small   4600.0  31.0
# 24              Dodge Shadow        Dodge    Small   5650.0  26.0
# 25              Dodge Spirit        Dodge  Compact   6650.0  24.5
# 26             Dodge Caravan        Dodge      Van   9500.0  19.0
# 27             Dodge Dynasty        Dodge  Midsize   7800.0  24.0
# 28             Dodge Stealth        Dodge   Sporty  12900.0  21.0
# 29              Eagle Summit        Eagle    Small   6100.0  31.0
# 30              Eagle Vision        Eagle    Large   9650.0  24.0
# ..                       ...          ...      ...      ...   ...
# 64             Nissan Sentra       Nissan    Small   5900.0  31.0
# 65             Nissan Altima       Nissan  Compact   7850.0  27.0
# 66              Nissan Quest       Nissan      Van   9550.0  20.0
# 67             Nissan Maxima       Nissan  Midsize  10750.0  23.5
# 68        Oldsmobile Achieva   Oldsmobile  Compact   6750.0  27.5
# 69  Oldsmobile Cutlass_Ciera   Oldsmobile  Midsize   8150.0  27.0
# 70     Oldsmobile Silhouette   Oldsmobile      Van   9750.0  20.5
# 71   Oldsmobile Eighty-Eight   Oldsmobile    Large  10350.0  23.5
# 72            Plymouth Laser     Plymouth   Sporty   7200.0  26.5
# 73            Pontiac LeMans      Pontiac    Small   4500.0  36.0
# 74           Pontiac Sunbird      Pontiac  Compact   5550.0  27.0
# 75          Pontiac Firebird      Pontiac   Sporty   8850.0  23.5
# 76        Pontiac Grand_Prix      Pontiac  Midsize   9250.0  23.0
# 77        Pontiac Bonneville      Pontiac    Large  12200.0  23.5
# 78                  Saab 900         Saab  Compact  14350.0  23.0
# 79                 Saturn SL       Saturn    Small   5550.0  33.0
# 80              Subaru Justy       Subaru    Small   4200.0  35.0
# 81             Subaru Loyale       Subaru    Small   5450.0  27.5
# 82             Subaru Legacy       Subaru  Compact   9750.0  26.5
# 83              Suzuki Swift       Suzuki    Small   4300.0  41.0
# 84             Toyota Tercel       Toyota    Small   4900.0  34.5
# 85             Toyota Celica       Toyota   Sporty   9200.0  28.5
# 86              Toyota Camry       Toyota  Midsize   9100.0  25.5
# 87             Toyota Previa       Toyota      Van  11350.0  20.0
# 88            Volkswagen Fox   Volkswagen    Small   4550.0  29.0
# 89        Volkswagen Eurovan   Volkswagen      Van   9850.0  19.0
# 90         Volkswagen Passat   Volkswagen  Compact  10000.0  25.5
# 91        Volkswagen Corrado   Volkswagen   Sporty  11650.0  21.5
# 92                 Volvo 240        Volvo  Compact  11350.0  24.5
# 93                 Volvo 850        Volvo  Midsize  13350.0  24.0
#
#     num_of_cylinders  horsepower  fuel_tank_capacity   rpm  wheelbase  \
# 1                  4         140                13.2  6300        102
# 2                  6         200                18.0  5500        115
# 3                  6         172                16.9  5500        102
# 4                  6         172                21.1  5500        106
# 5                  4         208                21.1  5700        109
# 6                  4         110                16.4  5200        105
# 7                  6         170                18.0  4800        111
# 8                  6         180                23.0  4000        116
# 9                  6         170                18.8  4800        108
# 10                 8         200                18.0  4100        114
# 11                 8         295                20.0  6000        111
# 12                 4         110                15.2  5200        101
# 13                 4         110                15.6  5200        103
# 14                 6         160                15.5  4600        101
# 15                 4         110                16.5  5200        108
# 16                 6         170                20.0  4800        110
# 17                 6         165                27.0  4000        111
# 18                 8         170                23.0  4200        116
# 19                 8         300                20.0  5000         96
# 20                 6         153                18.0  5300        113
# 21                 4         141                16.0  5000        104
# 22                 6         147                16.0  4800        110
# 23                 4          92                13.2  6000         98
# 24                 4          93                14.0  4800         97
# 25                 4         100                16.0  4800        104
# 26                 6         142                20.0  5000        112
# 27                 4         100                16.0  4800        105
# 28                 6         300                19.8  6000         97
# 29                 4          92                13.2  6000         98
# 30                 6         214                18.0  5800        113
# ..               ...         ...                 ...   ...        ...
# 64                 4         110                13.2  6000         96
# 65                 4         150                15.9  5600        103
# 66                 6         151                20.0  4800        112
# 67                 6         160                18.5  5200        104
# 68                 4         155                15.2  6000        103
# 69                 4         110                16.5  5200        105
# 70                 6         170                20.0  4800        110
# 71                 6         170                18.0  4800        111
# 72                 4          92                15.9  5000         97
# 73                 4          74                13.2  5600         99
# 74                 4         110                15.2  5200        101
# 75                 6         160                15.5  4600        101
# 76                 6         200                16.5  5000        108
# 77                 6         170                18.0  4800        111
# 78                 4         140                18.0  6000         99
# 79                 4          85                12.8  5000        102
# 80                 3          73                 9.2  5600         90
# 81                 4          90                15.9  5200         97
# 82                 4         130                15.9  5600        102
# 83                 3          70                10.6  6000         93
# 84                 4          82                11.9  5200         94
# 85                 4         135                15.9  5400         99
# 86                 4         130                18.5  5400        103
# 87                 4         138                19.8  5000        113
# 88                 4          81                12.4  5500         93
# 89                 5         109                21.1  4500        115
# 90                 4         134                18.5  5800        103
# 91                 6         178                18.5  5800         97
# 92                 4         114                15.8  5400        104
# 93                 5         168                19.3  6200        105
#
#     rear_seat_room  weight  automatic_gearbox  passenger_capacity  length  \
# 1        26.500000    2705              False                   5     177
# 2        30.000000    3560              False                   5     195
# 3        28.000000    3375              False                   5     180
# 4        31.000000    3405              False                   6     193
# 5        27.000000    3640              False                   4     186
# 6        28.000000    2880               True                   6     189
# 7        30.500000    3470               True                   6     200
# 8        30.500000    4105               True                   6     216
# 9        26.500000    3495               True                   5     198
# 10       35.000000    3620               True                   6     206
# 11       31.000000    3935               True                   5     204
# 12       25.000000    2490              False                   5     182
# 13       26.000000    2785              False                   5     184
# 14       25.000000    3240              False                   4     193
# 15       28.500000    3195               True                   6     198
# 16       30.500000    3715               True                   7     178
# 17       33.500000    4025               True                   8     194
# 18       29.500000    3910               True                   6     214
# 19       30.901059    3380              False                   2     179
# 20       31.000000    3515               True                   6     203
# 21       30.500000    3085               True                   6     183
# 22       36.000000    3570               True                   6     203
# 23       26.500000    2270              False                   5     174
# 24       26.500000    2670              False                   5     172
# 25       30.500000    2970              False                   6     181
# 26       26.500000    3705               True                   7     175
# 27       30.500000    3080               True                   6     192
# 28       20.000000    3805              False                   4     180
# 29       26.500000    2295              False                   5     174
# 30       30.000000    3490               True                   6     202
# ..             ...     ...                ...                 ...     ...
# 64       26.000000    2545              False                   5     170
# 65       28.500000    3050              False                   5     181
# 66       27.000000    4100               True                   7     190
# 67       28.500000    3200               True                   5     188
# 68       28.000000    2910               True                   5     188
# 69       28.000000    2890               True                   5     190
# 70       30.500000    3715               True                   7     194
# 71       31.500000    3470               True                   6     201
# 72       24.500000    2640              False                   4     173
# 73       25.500000    2350              False                   4     177
# 74       25.000000    2575              False                   5     181
# 75       25.000000    3240              False                   4     196
# 76       28.500000    3450              False                   5     195
# 77       30.500000    3495               True                   6     177
# 78       26.500000    2775              False                   5     184
# 79       26.500000    2495              False                   5     176
# 80       23.500000    2045              False                   4     146
# 81       27.500000    2490              False                   5     175
# 82       27.000000    3085              False                   5     179
# 83       27.500000    1965              False                   4     161
# 84       24.000000    2055              False                   5     162
# 85       23.000000    2950              False                   4     174
# 86       28.500000    3030              False                   5     188
# 87       35.000000    3785              False                   7     187
# 88       26.000000    2240              False                   4     163
# 89       34.000000    3960              False                   7     187
# 90       31.500000    2985              False                   5     180
# 91       26.000000    2810              False                   4     159
# 92       29.500000    2985              False                   5     190
# 93       30.000000    3245              False                   5     184
#
#     width  luggage_capacity             airbags drivetrain  origin
# 1      68         11.000000                None      Front    True
# 2      71         15.000000  DriverAndPassenger      Front    True
# 3      67         14.000000          DriverOnly      Front    True
# 4      70         17.000000  DriverAndPassenger      Front    True
# 5      69         13.000000          DriverOnly       Rear    True
# 6      69         16.000000          DriverOnly      Front   False
# 7      74         17.000000          DriverOnly      Front   False
# 8      78         21.000000          DriverOnly       Rear   False
# 9      73         14.000000          DriverOnly      Front   False
# 10     73         18.000000          DriverOnly      Front   False
# 11     74         14.000000  DriverAndPassenger      Front   False
# 12     66         13.000000                None      Front   False
# 13     68         14.000000          DriverOnly      Front   False
# 14     74         13.000000  DriverAndPassenger       Rear   False
# 15     71         16.000000                None      Front   False
# 16     74         16.820911                None      Front   False
# 17     78         18.361236                None        4WD   False
# 18     77         20.000000          DriverOnly       Rear   False
# 19     74         17.203669          DriverOnly       Rear   False
# 20     74         15.000000  DriverAndPassenger      Front   False
# 21     68         14.000000  DriverAndPassenger      Front   False
# 22     69         17.000000          DriverOnly      Front   False
# 23     66         11.000000                None      Front   False
# 24     67         13.000000          DriverOnly      Front   False
# 25     68         14.000000          DriverOnly      Front   False
# 26     72         14.937738          DriverOnly        4WD   False
# 27     69         16.000000          DriverOnly      Front   False
# 28     72         11.000000          DriverOnly        4WD   False
# 29     66         11.000000                None      Front   False
# 30     74         15.000000  DriverAndPassenger      Front   False
# ..    ...               ...                 ...        ...     ...
# 64     66         12.000000          DriverOnly      Front    True
# 65     67         14.000000          DriverOnly      Front    True
# 66     74         13.883075                None      Front    True
# 67     69         14.000000          DriverOnly      Front    True
# 68     67         14.000000                None      Front   False
# 69     70         16.000000          DriverOnly      Front   False
# 70     74         15.903808                None      Front   False
# 71     74         17.000000          DriverOnly      Front   False
# 72     67          8.000000                None        4WD   False
# 73     66         17.000000                None      Front   False
# 74     66         13.000000                None      Front   False
# 75     75         13.000000  DriverAndPassenger       Rear   False
# 76     72         16.000000                None      Front   False
# 77     74         18.000000  DriverAndPassenger      Front   False
# 78     67         14.000000          DriverOnly      Front    True
# 79     68         12.000000          DriverOnly      Front   False
# 80     60         10.000000                None        4WD    True
# 81     65         15.000000                None        4WD    True
# 82     67         14.000000          DriverOnly        4WD    True
# 83     63         10.000000                None      Front    True
# 84     65         11.000000          DriverOnly      Front    True
# 85     69         13.000000          DriverOnly      Front    True
# 86     70         15.000000          DriverOnly      Front    True
# 87     71         12.566363          DriverOnly        4WD    True
# 88     63         10.000000                None      Front    True
# 89     72         12.036724                None      Front    True
# 90     67         14.000000                None      Front    True
# 91     66         15.000000                None      Front    True
# 92     67         14.000000          DriverOnly       Rear    True
# 93     69         15.000000  DriverAndPassenger      Front    True
#
# [93 rows x 20 columns]

# %%
preprocessed_data = pd.read_pickle('datasets\\dummy_cartable.pkl')

# %%
dataset = Dataset(cartable, preprocessed_data)
# Out:
# C:\Users\d_mart04\Python\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %% [markdown]
# ### Configure PandaSQL to query Pandas dataframe

# %%
pysql = lambda q: pdsql.sqldf(q, globals())

# %% [markdown]
# ### Input Example
# ##### NOTE: Typos in examples provoke a fail in learning a query

# %%
example = pd.DataFrame(data=[
        ['chevrolet camaro', 7550.0, False], 
        ['Mustang', 7950.0, False],
        ['Firebird', 8850.0, False]], 
        columns=['model', 'price', 'automatic_gear'])

example['model'] = example['model'].astype('str')
example['price'] = example['price'].astype('float')
example['automatic_gear'] = example['automatic_gear'].astype('bool')
example
# Out:
#               model   price  automatic_gear
# 0  chevrolet camaro  7550.0           False
# 1           Mustang  7950.0           False
# 2          Firebird  8850.0           False

# %% [markdown]
# ##### Use the following code for lazy example acquisition:

# %% [raw]
# d_indices = [60, 70, 80]
# example = cartable[list(cartable.columns[2:5])].iloc[d_indices]
# print(example)
# print()
# show_images(d_indices)

# %% [markdown]
# ### Finding Project Predicates

# %%
def get_global_inverted_index(table, tablename='foo'):
    inverted_index = []
    for col in table.columns:
        for val in set(table[col].values):
            inverted_index.append([val, type(val), col, 'cartable'])
    return pd.DataFrame(data=inverted_index, columns=['Value', 'Type', 'Name', 'Table'])

# %%
# %time inverted_index = get_global_inverted_index(cartable, 'cartable')
# Out:
# Wall time: 2 ms

# %%
def get_project_columns_and_tables(inverted_index):
    columns_to_project = []
    tables_to_project = set()
    for attribute_example in [example[col][0] for col in example.columns]:
        selected_rows = inverted_index.loc[inverted_index['Type'] == type(attribute_example)]
        for index, row in selected_rows.iterrows():
            if type(attribute_example) is str:
                if str.lower(attribute_example) in str.lower(row['Value']):
                    tables_to_project.add(row['Table'])
                    columns_to_project.append(str.format('{0}.{1}', row['Table'], row['Name']))
            elif attribute_example == row['Value']:
                tables_to_project.add(row['Table'])
                columns_to_project.append(str.format('{0}.{1}', row['Table'], row['Name']))
    return columns_to_project, tables_to_project

# %%
# %time columns_to_project, tables_to_project = get_project_columns_and_tables(inverted_index)
# Out:
# Wall time: 24.9 ms

# %% [markdown]
# #### Presenting project query to the user

# %%
def get_projection_query_part(tables_to_project, columns_to_project):
    return 'SELECT ' + ', '.join(columns_to_project) + ' FROM ' + ', '.join(tables_to_project)

# %%
projection_query_part = get_projection_query_part(tables_to_project, columns_to_project)
projection_query_part
# Out:
# 'SELECT cartable.make, cartable.price, cartable.automatic_gearbox, cartable.origin FROM cartable'

# %% [markdown]
# #### Ask user for feedback on projection columns and tables. User can add/remove columns or change the order - TODO: Automatize it.

# %%
projection_query_part_after_feedback = 'SELECT cartable.make, cartable.price, cartable.automatic_gearbox FROM cartable'
projection_query_part_after_feedback
# Out:
# 'SELECT cartable.make, cartable.price, cartable.automatic_gearbox FROM cartable'

# %% [markdown]
# ### Finding selection predicates
# ##### The search space is composed by all tuples returned by joining the identified tables needed to produce the user example. If the database is composed by only one table, the search space is composed by all tuples in the table.
# ##### Positive tuples: All tuples containing the user example. Negative tuples: All remaining tuples.

# %%
resulting_tuples = pysql(projection_query_part_after_feedback)

# %%
def get_positive_and_negative_indices(resulting_tuples, example):
    positive_tuples_indices = set()
    negative_tuples_indices = set()

    for ex in example.values:
        for i in range(resulting_tuples.shape[0]):
            matched = []
            for j in range(resulting_tuples.shape[1]):
                if type(ex[j]) is str and str.lower(ex[j]) in str.lower(resulting_tuples.values[i][j]):
                    matched.append(True) 
                elif ex[j] == resulting_tuples.values[i][j]:
                    matched.append(True) 
                else:
                    matched.append(False)
            if False in matched:
                negative_tuples_indices.add(i)
            else:
                positive_tuples_indices.add(i)
                
    return positive_tuples_indices, negative_tuples_indices

# %%
# %time  positive_tuples_indices, negative_tuples_indices = get_positive_and_negative_indices(resulting_tuples, example)
# Out:
# Wall time: 62.8 ms

# %%
show_images(positive_tuples_indices)
# Out:
# ID:33 - Ford Mustang
# ID:74 - Pontiac Firebird
# ID:13 - Chevrolet Camaro

# %% [markdown]
# #### Using SOM to find semantic-related examples

# %%
som_selector = SomSelector(som_size=(10,10), num_iterations=2000, learning_rate=0.1, sigma=1.0)

# %%
def get_semantic_related_example_indices(som_selector, dataset, positive_indices):
    selected_indices = []
    for posidx in positive_indices:
        selected_indices.extend(som_selector.select(query=dataset.data_matrix[posidx], dataset=dataset, num_selected_items=3))
    return list(set(selected_indices))

# %%
# %time semantic_related_indices = get_semantic_related_example_indices(som_selector, dataset, positive_tuples_indices)
# Out:
# Wall time: 398 ms

# %%
show_images(semantic_related_indices)
# Out:
# ID:33 - Ford Mustang
# ID:74 - Pontiac Firebird
# ID:13 - Chevrolet Camaro
# ID:18 - Chevrolet Corvette
# ID:27 - Dodge Stealth

# %% [markdown]
# #### Asking user to adjust selected tuples
# ##### If semantic-related tuples are desired, use: positive_indices = semantic_related_indices; Otherwise: positive_indices = positive_tuples_indices

# %%
positive_indices = semantic_related_indices #[idx for idx in semantic_related_indices if not idx in [12, 40]]

# %% [markdown]
# #### Using a Decision Tree to find the selection predicates

# %%
decision_tree = DecisionTreeQBE(dataset.preprocessed_data, positive_indices)

# %%
# %time best_predicate = decision_tree.search_best_predicate()
# Out:
# Wall time: 997 µs

# %%
best_predicate
# Out:
# 'horsepower > 0.9916666746139526 OR horsepower <= 0.9916666746139526 AND type##Sporty## > 0.5 AND rpm <= 0.7384615540504456'

# %% [markdown]
# #### Converting predicate to original data

# %%
# Only works when enconded variables are binary
def preprocessed_predicate_to_original(predicate, cartable):
    original_predicate = predicate
    extracted_preds = []
    for and_pred in predicate.split('AND'):
        if 'OR' in and_pred:
            for or_pred in and_pred.split('OR'):
                extracted_preds.append(or_pred.strip())
        else:
            extracted_preds.append(and_pred.strip())

    for pred in extracted_preds:
        if '##' in pred:
            for col in cartable.columns:
                if col in pred:
                    encoded = re.split(r"##", pred)
                    equal = False
                    for op in ['>', '>=']:
                        if op in encoded[2]:
                            equal = True
                            break
                    if equal:
                        new_pred = str.format('{0} == \'{1}\'', encoded[0], encoded[1])
                    else:
                        new_pred = str.format('{0} <> \'{1}\'', encoded[0], encoded[1])
                    original_predicate = original_predicate.replace(pred, new_pred)
    
    return original_predicate

# %%
selection_predicate = preprocessed_predicate_to_original(best_predicate, cartable)

# %% [markdown]
# #### Evaluating predicate quality

# %%
output_view = pysql('SELECT * FROM cartable WHERE ' + selection_predicate)
util.get_information_retrieval_metrics(dataset.original_data, dataset.original_data.iloc[list(positive_indices)], output_view)
# Out:
# Relevant & Actual:  5
# Recall:  1.0
# Specificity:  0.0
# Precision:  0.053763440860215055
# F1-Score:  0.10204081632653061
# False negative rate:  0.0
# False positive rate:  1.0
# (1.0, 0.0, 0.053763440860215055, 0.10204081632653061)

# %% [markdown]
# ### Producing query

# %%
produced_query = projection_query_part_after_feedback + ' WHERE ' + selection_predicate
produced_query
# Out:
# "SELECT cartable.make, cartable.price, cartable.automatic_gearbox FROM cartable WHERE horsepower > 0.9916666746139526 OR horsepower <= 0.9916666746139526 AND type == 'Sporty' AND rpm <= 0.7384615540504456"

# %% [markdown]
# ### Visualizing results

# %%
produced_view = pysql(produced_query)
produced_view
# Out:
#                         make    price  automatic_gearbox
# 0              Acura Integra   7950.0                  0
# 1               Acura Legend  16950.0                  0
# 2                    Audi 90  14550.0                  0
# 3                   Audi 100  18850.0                  0
# 4                   BMW 535i  15000.0                  0
# 5              Buick Century   7850.0                  1
# 6              Buick LeSabre  10400.0                  1
# 7           Buick Roadmaster  11850.0                  1
# 8              Buick Riviera  13150.0                  1
# 9           Cadillac DeVille  17350.0                  1
# 10          Cadillac Seville  20050.0                  1
# 11        Chevrolet Cavalier   6700.0                  0
# 12         Chevrolet Corsica   5700.0                  0
# 13          Chevrolet Camaro   7550.0                  0
# 14          Chevrolet Lumina   7950.0                  1
# 15      Chevrolet Lumina_APV   8150.0                  1
# 16           Chevrolet Astro   8300.0                  1
# 17         Chevrolet Caprice   9400.0                  1
# 18        Chevrolet Corvette  19000.0                  0
# 19         Chrylser Concorde   9200.0                  1
# 20          Chrysler LeBaron   7900.0                  1
# 21         Chrysler Imperial  14750.0                  1
# 22                Dodge Colt   4600.0                  0
# 23              Dodge Shadow   5650.0                  0
# 24              Dodge Spirit   6650.0                  0
# 25             Dodge Caravan   9500.0                  1
# 26             Dodge Dynasty   7800.0                  1
# 27             Dodge Stealth  12900.0                  0
# 28              Eagle Summit   6100.0                  0
# 29              Eagle Vision   9650.0                  1
# ..                       ...      ...                ...
# 63             Nissan Sentra   5900.0                  0
# 64             Nissan Altima   7850.0                  0
# 65              Nissan Quest   9550.0                  1
# 66             Nissan Maxima  10750.0                  1
# 67        Oldsmobile Achieva   6750.0                  1
# 68  Oldsmobile Cutlass_Ciera   8150.0                  1
# 69     Oldsmobile Silhouette   9750.0                  1
# 70   Oldsmobile Eighty-Eight  10350.0                  1
# 71            Plymouth Laser   7200.0                  0
# 72            Pontiac LeMans   4500.0                  0
# 73           Pontiac Sunbird   5550.0                  0
# 74          Pontiac Firebird   8850.0                  0
# 75        Pontiac Grand_Prix   9250.0                  0
# 76        Pontiac Bonneville  12200.0                  1
# 77                  Saab 900  14350.0                  0
# 78                 Saturn SL   5550.0                  0
# 79              Subaru Justy   4200.0                  0
# 80             Subaru Loyale   5450.0                  0
# 81             Subaru Legacy   9750.0                  0
# 82              Suzuki Swift   4300.0                  0
# 83             Toyota Tercel   4900.0                  0
# 84             Toyota Celica   9200.0                  0
# 85              Toyota Camry   9100.0                  0
# 86             Toyota Previa  11350.0                  0
# 87            Volkswagen Fox   4550.0                  0
# 88        Volkswagen Eurovan   9850.0                  0
# 89         Volkswagen Passat  10000.0                  0
# 90        Volkswagen Corrado  11650.0                  0
# 91                 Volvo 240  11350.0                  0
# 92                 Volvo 850  13350.0                  0
#
# [93 rows x 3 columns]

# %% [markdown]
# ### Playground

# %%
class Preference(object):
    def __init__(self, tablename, column, operator, value):
        self.tablename = tablename
        self.column = column
        self.operator = operator
        self.value = value
        
    def __str__(self):
        return str.format('{{0}\[{1}\]} {2} {3}', self.tablename, self.column, self.operator, self.value)
    
    def use(self):
        return str.format('{0} {1} {2}', self.column, self.operator, self.value)

# %%
my_preference = Preference('cartable', 'price', '<=', example['price'].median())

# %%
query = str.format('{0} AND {1}', produced_query, my_preference.use())
view = pysql(query)
view
# Out:
#                         make    price  automatic_gearbox
# 0              Acura Integra   7950.0                  0
# 1               Acura Legend  16950.0                  0
# 2                    Audi 90  14550.0                  0
# 3                   Audi 100  18850.0                  0
# 4                   BMW 535i  15000.0                  0
# 5              Buick Century   7850.0                  1
# 6              Buick LeSabre  10400.0                  1
# 7           Buick Roadmaster  11850.0                  1
# 8              Buick Riviera  13150.0                  1
# 9           Cadillac DeVille  17350.0                  1
# 10          Cadillac Seville  20050.0                  1
# 11        Chevrolet Cavalier   6700.0                  0
# 12         Chevrolet Corsica   5700.0                  0
# 13          Chevrolet Camaro   7550.0                  0
# 14          Chevrolet Lumina   7950.0                  1
# 15      Chevrolet Lumina_APV   8150.0                  1
# 16           Chevrolet Astro   8300.0                  1
# 17         Chevrolet Caprice   9400.0                  1
# 18        Chevrolet Corvette  19000.0                  0
# 19         Chrylser Concorde   9200.0                  1
# 20          Chrysler LeBaron   7900.0                  1
# 21         Chrysler Imperial  14750.0                  1
# 22                Dodge Colt   4600.0                  0
# 23              Dodge Shadow   5650.0                  0
# 24              Dodge Spirit   6650.0                  0
# 25             Dodge Caravan   9500.0                  1
# 26             Dodge Dynasty   7800.0                  1
# 27             Dodge Stealth  12900.0                  0
# 28              Eagle Summit   6100.0                  0
# 29              Eagle Vision   9650.0                  1
# ..                       ...      ...                ...
# 63             Nissan Sentra   5900.0                  0
# 64             Nissan Altima   7850.0                  0
# 65              Nissan Quest   9550.0                  1
# 66             Nissan Maxima  10750.0                  1
# 67        Oldsmobile Achieva   6750.0                  1
# 68  Oldsmobile Cutlass_Ciera   8150.0                  1
# 69     Oldsmobile Silhouette   9750.0                  1
# 70   Oldsmobile Eighty-Eight  10350.0                  1
# 71            Plymouth Laser   7200.0                  0
# 72            Pontiac LeMans   4500.0                  0
# 73           Pontiac Sunbird   5550.0                  0
# 74          Pontiac Firebird   8850.0                  0
# 75        Pontiac Grand_Prix   9250.0                  0
# 76        Pontiac Bonneville  12200.0                  1
# 77                  Saab 900  14350.0                  0
# 78                 Saturn SL   5550.0                  0
# 79              Subaru Justy   4200.0                  0
# 80             Subaru Loyale   5450.0                  0
# 81             Subaru Legacy   9750.0                  0
# 82              Suzuki Swift   4300.0                  0
# 83             Toyota Tercel   4900.0                  0
# 84             Toyota Celica   9200.0                  0
# 85              Toyota Camry   9100.0                  0
# 86             Toyota Previa  11350.0                  0
# 87            Volkswagen Fox   4550.0                  0
# 88        Volkswagen Eurovan   9850.0                  0
# 89         Volkswagen Passat  10000.0                  0
# 90        Volkswagen Corrado  11650.0                  0
# 91                 Volvo 240  11350.0                  0
# 92                 Volvo 850  13350.0                  0
#
# [93 rows x 3 columns]

# %%
util.get_information_retrieval_metrics(dataset.original_data, dataset.original_data.iloc[list(positive_indices)], view)
# Out:
# Relevant & Actual:  0
# Recall:  0.0
# Specificity:  1.0
# Precision:  0.0
# F1-Score:  0
# False negative rate:  1.0
# False positive rate:  0.0
# (0.0, 1.0, 0.0, 0)

# %%
american_sportive_cars = pysql("SELECT * FROM cartable WHERE origin = 0 AND type = 'Sporty'")
american_sportive_cars
# Out:
#                  make manufacturer    type    price   mpg  num_of_cylinders  \
# 0    Chevrolet Camaro    Chevrolet  Sporty   7550.0  23.5                 6
# 1  Chevrolet Corvette    Chevrolet  Sporty  19000.0  21.0                 8
# 2       Dodge Stealth        Dodge  Sporty  12900.0  21.0                 6
# 3        Ford Mustang         Ford  Sporty   7950.0  25.5                 4
# 4          Ford Probe         Ford  Sporty   7000.0  27.0                 4
# 5       Mercury Capri      Mercury  Sporty   7050.0  24.5                 4
# 6      Plymouth Laser     Plymouth  Sporty   7200.0  26.5                 4
# 7    Pontiac Firebird      Pontiac  Sporty   8850.0  23.5                 6
#
#    horsepower  fuel_tank_capacity   rpm  wheelbase  rear_seat_room  weight  \
# 0         160                15.5  4600        101       25.000000    3240
# 1         300                20.0  5000         96       30.901059    3380
# 2         300                19.8  6000         97       20.000000    3805
# 3         105                15.4  4600        101       24.000000    2850
# 4         115                15.5  5500        103       23.000000    2710
# 5         100                11.1  5750         95       19.000000    2450
# 6          92                15.9  5000         97       24.500000    2640
# 7         160                15.5  4600        101       25.000000    3240
#
#    automatic_gearbox  passenger_capacity  length  width  luggage_capacity  \
# 0                  0                   4     193     74         13.000000
# 1                  0                   2     179     74         17.203669
# 2                  0                   4     180     72         11.000000
# 3                  0                   4     180     68         12.000000
# 4                  0                   4     179     70         18.000000
# 5                  0                   4     166     65          6.000000
# 6                  0                   4     173     67          8.000000
# 7                  0                   4     196     75         13.000000
#
#               airbags drivetrain  origin
# 0  DriverAndPassenger       Rear       0
# 1          DriverOnly       Rear       0
# 2          DriverOnly        4WD       0
# 3          DriverOnly       Rear       0
# 4          DriverOnly      Front       0
# 5          DriverOnly      Front       0
# 6                None        4WD       0
# 7  DriverAndPassenger       Rear       0
